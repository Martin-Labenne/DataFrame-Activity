# %%
import pandas as pd
from matplotlib import pyplot as plt

# %% [markdown]
# # Ouverture de 60s, 70s et 80s

# %%
sixties = pd.read_csv('60s.csv', index_col = 0)
seventies = pd.read_csv('70s.csv', index_col = 0)
heighties = pd.read_csv('80s.csv', index_col = 0)

# %% [markdown]
# # Graph

# %%
plt.rcParams.update({'font.size': 14})

# %%
plt.figure(figsize=(9,5))
plt.scatter(sixties.index, sixties['births'], c='blue', label='sixties')
#plt.scatter(seventies.index, seventies['births'], c='red', label='seventies')
#plt.scatter(heighties.index, heighties['births'], c='green', label='heighties')
plt.legend()
plt.show()
